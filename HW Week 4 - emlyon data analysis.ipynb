# %% [markdown]
# # Homework : Time Series

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
# %matplotlib inline

# %%
obj_trouves = pd.read_csv('data1/objets-trouves-restitution.csv',sep = ';',parse_dates=True, index_col = "Date")

# %%
obj_trouves.head()
# Out:
#                           Date et heure de restitution            Gare  \
# Date
# 2017-06-20 16:05:25+02:00                          NaN           Nîmes
# 2017-08-10 17:33:37+02:00    2017-08-11T16:13:06+02:00  Boulogne Ville
# 2017-07-03 10:57:43+02:00                          NaN           Nîmes
# 2017-08-11 09:26:05+02:00    2017-08-11T16:16:52+02:00           Dijon
# 2017-07-11 10:13:04+02:00                          NaN           Nîmes
#
#                              Code UIC  \
# Date
# 2017-06-20 16:05:25+02:00  87775007.0
# 2017-08-10 17:33:37+02:00  87317586.0
# 2017-07-03 10:57:43+02:00  87775007.0
# 2017-08-11 09:26:05+02:00  87713040.0
# 2017-07-11 10:13:04+02:00  87775007.0
#
#                                                           Nature d'objets  \
# Date
# 2017-06-20 16:05:25+02:00  Sac de voyage, sac de sport, sac à bandoulière
# 2017-08-10 17:33:37+02:00                              Téléphone portable
# 2017-07-03 10:57:43+02:00                                       Sac à dos
# 2017-08-11 09:26:05+02:00                                       Sac à dos
# 2017-07-11 10:13:04+02:00                                Clés, porte-clés
#
#                                                                Type d'objets  \
# Date
# 2017-06-20 16:05:25+02:00                Bagagerie: sacs, valises, cartables
# 2017-08-10 17:33:37+02:00  Appareils électroniques, informatiques, appare...
# 2017-07-03 10:57:43+02:00                Bagagerie: sacs, valises, cartables
# 2017-08-11 09:26:05+02:00                Bagagerie: sacs, valises, cartables
# 2017-07-11 10:13:04+02:00                 Clés, porte-clés, badge magnétique
#
#                           Type d'enregistrement
# Date
# 2017-06-20 16:05:25+02:00          Objet trouvé
# 2017-08-10 17:33:37+02:00          Objet trouvé
# 2017-07-03 10:57:43+02:00          Objet trouvé
# 2017-08-11 09:26:05+02:00          Objet trouvé
# 2017-07-11 10:13:04+02:00          Objet trouvé

# %%
obj_trouves['Type d\'enregistrement'].value_counts()
# Out:
# Objet trouvé    388268
# Name: Type d'enregistrement, dtype: int64

# %% [markdown]
# ## we can delete the column Type d'enregistrement

# %%
obj_trouves.drop('Type d\'enregistrement', axis = 1 , inplace = True)

# %% [markdown]
# ## Q1: Modify dates in index from 'YYYY-MM-DD HH:MM:SS' format to 'YYYY-MM-DD' format
# - Ex: 2017-07-03 08:57:43 --> 2017-07-03
# - Save the result in place(I mean indexes of obj_trouves must be changed)
#
# Be careful to keep DateTimeIndex, you can do obj_trouves.index = pd.to_datetime(obj_trouves.index)

# %%
obj_trouves.index = pd.to_datetime(obj_trouves.index,utc=True)
obj_trouves.index = pd.to_datetime(obj_trouves.index.date)
obj_trouves.index.name='Date'


obj_trouves.head()
#obj_trouves.index.date
# Out:
#            Date et heure de restitution            Gare    Code UIC  \
# Date
# 2017-06-20                          NaN           Nîmes  87775007.0
# 2017-08-10    2017-08-11T16:13:06+02:00  Boulogne Ville  87317586.0
# 2017-07-03                          NaN           Nîmes  87775007.0
# 2017-08-11    2017-08-11T16:16:52+02:00           Dijon  87713040.0
# 2017-07-11                          NaN           Nîmes  87775007.0
#
#                                            Nature d'objets  \
# Date
# 2017-06-20  Sac de voyage, sac de sport, sac à bandoulière
# 2017-08-10                              Téléphone portable
# 2017-07-03                                       Sac à dos
# 2017-08-11                                       Sac à dos
# 2017-07-11                                Clés, porte-clés
#
#                                                 Type d'objets
# Date
# 2017-06-20                Bagagerie: sacs, valises, cartables
# 2017-08-10  Appareils électroniques, informatiques, appare...
# 2017-07-03                Bagagerie: sacs, valises, cartables
# 2017-08-11                Bagagerie: sacs, valises, cartables
# 2017-07-11                 Clés, porte-clés, badge magnétique

# %%
obj_trouves.index.day
# Out:
# Int64Index([20, 10,  3, 11, 11, 18, 11, 11, 11, 28,
#             ...
#             29,  4,  5,  2, 25,  5,  4,  3,  5, 17],
#            dtype='int64', name='Date', length=388268)

# %%
obj_trouves['2013-05-24']
#this pre-entered code did not work in my notebook
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-659f7d864737> in <module>
# ----> 1 obj_trouves['2013-05-24']
#       2 #obj_trouves.tail()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2883             # either we have a slice or we have a string that can be converted
#    2884             #  to a slice for partial-string date indexing
# -> 2885             return self._slice(indexer, axis=0)
#    2886
#    2887         # Do we have a (boolean) DataFrame?
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3555         Slicing with this method is *always* positional.
#    3556         """
# -> 3557         assert isinstance(slobj, slice), type(slobj)
#    3558         axis = self._get_block_manager_axis(axis)
#    3559         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#
# AssertionError: <class 'numpy.ndarray'>

# %%
obj_trouves.loc['2013-05-24']
# I went ahead and changed that since we need to call an index differently than a column
# Out:
#            Date et heure de restitution                              Gare  \
# Date
# 2013-05-24                          NaN                        Strasbourg
# 2013-05-24                          NaN                        Strasbourg
# 2013-05-24                          NaN                        Strasbourg
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24    2013-05-27T09:38:56+02:00                        Strasbourg
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24    2013-05-24T13:03:53+02:00                        Strasbourg
# 2013-05-24                          NaN                        Strasbourg
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24    2013-05-27T06:24:17+02:00                        Strasbourg
# 2013-05-24                          NaN  Aéroport Charles de Gaulle 2 TGV
# 2013-05-24                          NaN                        Strasbourg
# 2013-05-24                          NaN                Paris Saint-Lazare
# 2013-05-24    2013-06-04T08:56:32+02:00                Paris Saint-Lazare
#
#               Code UIC                                   Nature d'objets  \
# Date
# 2013-05-24  87212027.0                                Carte d'abonnement
# 2013-05-24  87212027.0                          Autres divers (préciser)
# 2013-05-24  87212027.0                                Téléphone portable
# 2013-05-24  87384008.0             Article de papéterie, stylo, classeur
# 2013-05-24  87384008.0      Manteau, veste, blazer, parka, blouson, cape
# 2013-05-24  87384008.0                                  Foulard, écharpe
# 2013-05-24  87212027.0  Appareil photo, caméscope/caméras et accessoires
# 2013-05-24  87384008.0    Sac de voyage, sac de sport, sac à bandoulière
# 2013-05-24  87384008.0                       Porte-monnaie, portefeuille
# 2013-05-24  87212027.0                          Autres divers (préciser)
# 2013-05-24  87212027.0                       Autres vêtements (préciser)
# 2013-05-24  87384008.0               Autres articles médicaux (préciser)
# 2013-05-24  87212027.0                                Téléphone portable
# 2013-05-24  87271494.0                                  Clés, porte-clés
# 2013-05-24  87212027.0           Autres articles de papeterie (préciser)
# 2013-05-24  87384008.0    Sac de voyage, sac de sport, sac à bandoulière
# 2013-05-24  87384008.0                                   Carte de crédit
#
#                                                 Type d'objets
# Date
# 2013-05-24           Pièces d'identités et papiers personnels
# 2013-05-24                                             Divers
# 2013-05-24  Appareils électroniques, informatiques, appare...
# 2013-05-24                      Livres, articles de papéterie
# 2013-05-24                              Vêtements, chaussures
# 2013-05-24                              Vêtements, chaussures
# 2013-05-24  Appareils électroniques, informatiques, appare...
# 2013-05-24                Bagagerie: sacs, valises, cartables
# 2013-05-24       Porte-monnaie / portefeuille, argent, titres
# 2013-05-24                                             Divers
# 2013-05-24                              Vêtements, chaussures
# 2013-05-24                                  Articles médicaux
# 2013-05-24  Appareils électroniques, informatiques, appare...
# 2013-05-24                 Clés, porte-clés, badge magnétique
# 2013-05-24                      Livres, articles de papéterie
# 2013-05-24                Bagagerie: sacs, valises, cartables
# 2013-05-24       Porte-monnaie / portefeuille, argent, titres

# %%
obj_trouves.tail()
# Out:
#            Date et heure de restitution                    Gare    Code UIC  \
# Date
# 2017-11-05                          NaN                  Rennes  87471003.0
# 2017-11-04                          NaN  Montpellier Saint-Roch  87773002.0
# 2017-11-03                          NaN                Chartres  87394007.0
# 2017-11-05                          NaN                  Rennes  87471003.0
# 2017-10-17                          NaN                  Rennes  87471003.0
#
#                                               Nature d'objets  \
# Date
# 2017-11-05       Manteau, veste, blazer, parka, blouson, cape
# 2017-11-04                                   Pull over, gilet
# 2017-11-03                                          Sac à dos
# 2017-11-05                                   Foulard, écharpe
# 2017-10-17  Autres appareils et accessoires électroniques ...
#
#                                                 Type d'objets
# Date
# 2017-11-05                              Vêtements, chaussures
# 2017-11-04                              Vêtements, chaussures
# 2017-11-03                Bagagerie: sacs, valises, cartables
# 2017-11-05                              Vêtements, chaussures
# 2017-10-17  Appareils électroniques, informatiques, appare...

# %% [markdown]
# ## Q2: Pivot obj_trouves to get a new dataframe with hierarchical indexing : Date and station (Gare) (BE CAREFUL OF THE ORDER)
# The values are the number of found objects per station for each Date (if at least one object is lost)
#
# Hints:
# - Use only one column, 'Type d'objets' or 'Nature d'objet'
# - Use the aggregate function len to count the number of found objects
#
# Number_found_objects  = string.count(substring)

# %%
pivoted_obj_trouves = pd.pivot_table(obj_trouves, index=['Date','Gare'],values=['Nature d\'objets'],aggfunc=len)
pivoted_obj_trouves
# Out:
#                                              Nature d'objets
# Date       Gare
# 2013-05-24 Aéroport Charles de Gaulle 2 TGV                1
#            Paris Saint-Lazare                              8
#            Strasbourg                                      8
# 2013-05-25 Strasbourg                                      9
# 2013-05-26 Strasbourg                                      2
# ...                                                      ...
# 2017-11-05 Paris Gare de Lyon                              3
#            Quimper                                         1
#            Rennes                                         14
#            Strasbourg                                      3
#            Toulon                                          1
#
# [76241 rows x 1 columns]

# %% [markdown]
# ## Q3: Change the name of the column to 'Nb of found objects'

# %%
pivoted_obj_trouves = pivoted_obj_trouves.rename(columns={"Nature d'objets": "Nb of found objects"})
pivoted_obj_trouves
# Out:
#                                              Nb of found objects
# Date       Gare
# 2013-05-24 Aéroport Charles de Gaulle 2 TGV                    1
#            Paris Saint-Lazare                                  8
#            Strasbourg                                          8
# 2013-05-25 Strasbourg                                          9
# 2013-05-26 Strasbourg                                          2
# ...                                                          ...
# 2017-11-05 Paris Gare de Lyon                                  3
#            Quimper                                             1
#            Rennes                                             14
#            Strasbourg                                          3
#            Toulon                                              1
#
# [76241 rows x 1 columns]

# %% [markdown]
# ## Q4: Get the date and the station with the greatest number of found objects (Find this greatest number as well)

# %%
maxind = pivoted_obj_trouves['Nb of found objects'].idxmax()
maxind
# Out:
# (Timestamp('2017-09-26 00:00:00'), 'Paris Gare de Lyon')

# %%
foundobj_ind = pivoted_obj_trouves.index.get_loc(maxind)
foundobj_ind
# Out:
# 73899

# %%
pivoted_obj_trouves.iloc[foundobj_ind]
# Out:
# Nb of found objects    121
# Name: (2017-09-26 00:00:00, Paris Gare de Lyon), dtype: int64

# %% [markdown]
# ## Q5: Print a barplot showing number of found objects per station for the date found in Q4

# %%
pivoted_obj_trouves.loc[maxind[0]].plot(y="Nb of found objects", kind="bar")
plt.show()

# %% [markdown]
# ## Q6: Create a new dataframe indexed by the type of objects with one column for the numbers of found objects for each type in 2016

# %%
obj_trouves_type = pd.pivot_table(obj_trouves.loc["2016"], index=["Type d'objets"], values=["Nature d'objets"], aggfunc=len)
obj_trouves_type
# Out:
#                                                     Nature d'objets
# Type d'objets
# Appareils électroniques, informatiques, apparei...            13603
# Articles d'enfants, de puériculture                            1227
# Articles de sport, loisirs, camping                            1143
# Articles médicaux                                               621
# Bagagerie: sacs, valises, cartables                           27197
# Bijoux, montres                                                 962
# Clés, porte-clés, badge magnétique                             5031
# Divers                                                         1839
# Instruments de musique                                          229
# Livres, articles de papéterie                                  2591
# Optique                                                        5838
# Parapluies                                                     1258
# Pièces d'identités et papiers personnels                       8735
# Porte-monnaie / portefeuille, argent, titres                  11452
# Vélos, trotinettes, accessoires 2 roues                        1028
# Vélos, trottinettes, accessoires 2 roues                       1028
# Vêtements, chaussures                                         12825

# %%
obj_trouves_type = obj_trouves_type.rename(columns={"Nature d'objets": "Nb of found objects"})
obj_trouves_type
# Out:
#                                                     Nb of found objects
# Type d'objets
# Appareils électroniques, informatiques, apparei...                13603
# Articles d'enfants, de puériculture                                1227
# Articles de sport, loisirs, camping                                1143
# Articles médicaux                                                   621
# Bagagerie: sacs, valises, cartables                               27197
# Bijoux, montres                                                     962
# Clés, porte-clés, badge magnétique                                 5031
# Divers                                                             1839
# Instruments de musique                                              229
# Livres, articles de papéterie                                      2591
# Optique                                                            5838
# Parapluies                                                         1258
# Pièces d'identités et papiers personnels                           8735
# Porte-monnaie / portefeuille, argent, titres                      11452
# Vélos, trotinettes, accessoires 2 roues                            1028
# Vélos, trottinettes, accessoires 2 roues                           1028
# Vêtements, chaussures                                             12825

# %% [markdown]
# ## Q7 Plot a decreasing bar chart of the number of founds objects regarding types from the dataframe made in Q6

# %%
obj_trouves_type.sort_values("Nb of found objects", ascending=False).plot(y="Nb of found objects", kind="bar")
plt.show()

# %% [markdown]
# ## Q8: Create a pivot table to analyse sales regarding Customer Segments and product categories
#
# We are intersted by different indicators : number of sales, median and sum of sales
#
# Hint : use one index, one column, one value and three aggfunc

# %%
stores = pd.read_csv("data/SuperstoreSales.csv", encoding="latin1", parse_dates=["Order Date"])
stores.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode  Unit Price  Shipping Cost       Customer Name  \
# 0      0.04     Regular Air       38.94          35.00  Muhammed MacIntyre
# 1      0.07  Delivery Truck      208.16          68.02        Barry French
# 2      0.01     Regular Air        8.69           2.99        Barry French
# 3      0.08     Regular Air      195.99           3.99       Clay Rozendal
# 4      0.08     Regular Air       21.78           5.94      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Nunavut  Nunavut         Consumer  Office Supplies
# 2  Nunavut  Nunavut         Consumer  Office Supplies
# 3  Nunavut  Nunavut        Corporate       Technology
# 4  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
# 3    Telephones and Communication
# 4                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D¨ Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#    Product Base Margin Ship Date
# 0                 0.80  10/20/10
# 1                 0.58   10/2/12
# 2                 0.39   10/3/12
# 3                 0.58   7/12/11
# 4                 0.50   8/30/10

# %%
pivoted_sales= pd.pivot_table(stores, index=['Customer Segment'], columns=['Product Category'], values=['Sales'], aggfunc = [np.count_nonzero, np.median, np.sum])
pivoted_sales
# Out:
#                  count_nonzero                               median  \
#                          Sales                                Sales
# Product Category     Furniture Office Supplies Technology Furniture
# Customer Segment
# Consumer                 358.0           865.0      426.0  1366.373
# Corporate                633.0          1680.0      763.0  1323.670
# Home Office              406.0          1145.0      481.0  1571.980
# Small Business           327.0           920.0      395.0  1217.620
#
#                                                      sum                  \
#                                                    Sales
# Product Category Office Supplies Technology    Furniture Office Supplies
# Customer Segment
# Consumer                 207.190   1074.065  1128807.214       691382.23
# Corporate                205.475   1313.640  1862840.574      1341315.63
# Home Office              223.640   1298.290  1285345.918       960054.41
# Small Business           202.475   1383.919   901596.836       760009.83
#
#
#
# Product Category    Technology
# Customer Segment
# Consumer          1.243422e+06
# Corporate         2.294749e+06
# Home Office       1.319364e+06
# Small Business    1.126714e+06

# %% [markdown]
# ## Q9: Plot 3 bar plots, one for each indicator (number of sales, median, sum)
#
# Each graph will have three bars representing product categories for each customer segment

# %%
pivoted_sales.columns
# Out:
# MultiIndex([('count_nonzero', 'Sales',       'Furniture'),
#             ('count_nonzero', 'Sales', 'Office Supplies'),
#             ('count_nonzero', 'Sales',      'Technology'),
#             (       'median', 'Sales',       'Furniture'),
#             (       'median', 'Sales', 'Office Supplies'),
#             (       'median', 'Sales',      'Technology'),
#             (          'sum', 'Sales',       'Furniture'),
#             (          'sum', 'Sales', 'Office Supplies'),
#             (          'sum', 'Sales',      'Technology')],
#            names=[None, None, 'Product Category'])

# %%
pivoted_sales["count_nonzero", "Sales"]
# Out:
# Product Category  Furniture  Office Supplies  Technology
# Customer Segment
# Consumer              358.0            865.0       426.0
# Corporate             633.0           1680.0       763.0
# Home Office           406.0           1145.0       481.0
# Small Business        327.0            920.0       395.0

# %%
pivoted_sales["count_nonzero","Sales"].plot(y=["Furniture","Office Supplies","Technology"],kind="bar")
# Out:
# <AxesSubplot:xlabel='Customer Segment'>

# %%
pivoted_sales["median","Sales"].plot(y=["Furniture","Office Supplies","Technology"],kind="bar")
# Out:
# <AxesSubplot:xlabel='Customer Segment'>

# %%
pivoted_sales["sum","Sales"].plot(y=["Furniture","Office Supplies","Technology"],kind="bar")
# Out:
# <AxesSubplot:xlabel='Customer Segment'>
